# %%
import tweepy
import csv
import pandas as pd
####input your credentials here
consumer_key = 'k8i8P4j8QrZW6ZEZo74USuRV7'
consumer_secret = 'ODcowaFCSoX8MGzkzGMH4YthEUWvHOOcVw23EsfrSPNljjyhOM'
access_token = '1257047286468751363-3SujcGuqZfXutbfeScFdkj3Nf8ERCg'
access_token_secret = 'kcLeKHO284S7oXxbr8fPVKQKFQkNodLbEcmT4VwozhtTo'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data
csvFile = open('zak.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#Justice4ZakZackie",count=1000,
                           lang="en",
                           since="2020-04-03").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2020-12-22 18:01:40 RT @SebastienTULLER: “#Zak’s killing and the initial reporting of the case, filled with stigmatising remarks and reproduction of fake news,…
# 2020-12-22 15:24:10 RT @SebastienTULLER: “#Zak’s killing and the initial reporting of the case, filled with stigmatising remarks and reproduction of fake news,…
# 2020-12-22 15:23:48 RT @SebastienTULLER: “#Zak’s killing and the initial reporting of the case, filled with stigmatising remarks and reproduction of fake news,…
# 2020-12-22 15:22:28 “#Zak’s killing and the initial reporting of the case, filled with stigmatising remarks and reproduction of fake ne… https://t.co/vhqnCIQpNo
# 2020-12-22 13:50:31 #Justice4ZakZackie T-shirts for Zackie screen-printed and sold to support court costs. Zak Kostopoulos @zakkost (ak… https://t.co/O2vVFQPIhZ
# 2020-12-22 05:51:25 RT @VassilisTsarnas: #Greece: "‘#LGBT activist #ZakKostopoulos’s family say murder charges must be brought in a case that has exposed deep…
# ...
